# %%
import matplotlib.pyplot as plt
import numpy as np
num = []
for i in range(0,721,10):
    num.append(i)
num  = np.radians(num)
y = np.sin(num)
plt.xlabel("Radians")
plt.ylabel("sine of radians")
plt.plot(num,y)
