# %%
import numpy as np
import pandas as pd 
from sklearn.metrics import r2_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
dataset = pd.read_csv("Housing.csv")
x = dataset.iloc[:,1:]
y = dataset.iloc[:,0].values
encode_column = ['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(),encode_column)], remainder="passthrough")
x= ct.fit_transform(x)
x_train ,x_test, y_train,y_test=train_test_split(x,y,random_state=0, test_size=0.2)
poly = PolynomialFeatures(degree=7)
x_poly = poly.fit_transform(x_train)
model = LinearRegression()
model.fit(x_poly,y_train)
y_pred = model.predict(poly.fit_transform(x_test))
print(r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 19
#      17 x_poly = poly.fit_transform(x_train)
#      18 model = LinearRegression()
# ---> 19 model.fit(x_poly,y_train)
#      20 y_pred = model.predict(poly.fit_transform(x_test))
#      21 print(r2_score(y_test,y_pred))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:639, in LinearRegression.fit(self, X, y, sample_weight)
#     634 # Note that neither _rescale_data nor the rest of the fit method of
#     635 # LinearRegression can benefit from in-place operations when X is a
#     636 # sparse matrix. Therefore, let's not copy X when it is sparse.
#     637 copy_X_in_preprocess_data = self.copy_X and not sp.issparse(X)
# --> 639 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     640     X,
#     641     y,
#     642     fit_intercept=self.fit_intercept,
#     643     copy=copy_X_in_preprocess_data,
#     644     sample_weight=sample_weight,
#     645 )
#     647 if has_sw:
#     648     # Sample weight can be implemented via a simple rescaling. Note
#     649     # that we safely do inplace rescaling when _preprocess_data has
#     650     # already made a copy if requested.
#     651     X, y, sample_weight_sqrt = _rescale_data(
#     652         X, y, sample_weight, inplace=copy_X_in_preprocess_data
#     653     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py:167, in _preprocess_data(X, y, fit_intercept, copy, copy_y, sample_weight, check_input)
#     164     sample_weight = xp.asarray(sample_weight)
#     166 if check_input:
# --> 167     X = check_array(
#     168         X, copy=copy, accept_sparse=["csr", "csc"], dtype=supported_float_dtypes(xp)
#     169     )
#     170     y = check_array(y, dtype=X.dtype, copy=copy_y, ensure_2d=False)
#     171 else:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1116, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1113 if _is_numpy_namespace(xp):
#    1114     # only make a copy if `array` and `array_orig` may share memory`
#    1115     if np.may_share_memory(array, array_orig):
# -> 1116         array = _asarray_with_order(
#    1117             array, dtype=dtype, order=order, copy=True, xp=xp
#    1118         )
#    1119 else:
#    1120     # always make a copy for non-numpy arrays
#    1121     array = _asarray_with_order(
#    1122         array, dtype=dtype, order=order, copy=True, xp=xp
#    1123     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_array_api.py:755, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     752 if _is_numpy_namespace(xp):
#     753     # Use NumPy API to support order
#     754     if copy is True:
# --> 755         array = numpy.array(array, order=order, dtype=dtype)
#     756     else:
#     757         array = numpy.asarray(array, order=order, dtype=dtype)
#
# MemoryError: Unable to allocate 2.88 GiB for an array with shape (436, 888030) and data type float64
